# %%
def keras_plotter(history):
    import pandas as pd
    import matplotlib.pyplot as plt
    
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,2)
    plt.savefig("parte_temp.jpeg")
    plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10

(x_train_val, y_train_val), (x_test, y_test) = cifar10.load_data()

from sklearn.model_selection import StratifiedShuffleSplit
strat_split=StratifiedShuffleSplit(n_splits=1,test_size=0.2)
for train_index,test_index in strat_split.split(x_train_val,y_train_val):
    x_train,y_train=x_train_val[train_index],y_train_val[train_index]
    x_val,y_val=x_train_val[test_index],y_train_val[test_index]
    
x_train_val=x_train_val.reshape((50000,3072))
x_train=x_train.reshape((40000,3072))
x_val=x_val.reshape((10000,3072))
x_test=x_test.reshape((10000,3072))

from sklearn.preprocessing import StandardScaler
sta_scal=StandardScaler()
sta_scal.fit(x_train)
x_train_val=sta_scal.transform(x_train_val)
x_train=sta_scal.transform(x_train)
x_val=sta_scal.transform(x_val)
x_test=sta_scal.transform(x_test)


x_train_val=x_train_val.reshape((50000,32, 32, 3))
x_train=x_train.reshape((40000,32, 32, 3))
x_val=x_val.reshape((10000,32, 32, 3))
x_test=x_test.reshape((10000,32, 32, 3))


y_train_val=keras.utils.to_categorical(y_train_val,10)
y_train=keras.utils.to_categorical(y_train,10)
y_val=keras.utils.to_categorical(y_val,10)
y_test=keras.utils.to_categorical(y_test,10)

# %%
#HyperParameters Definition
import tensorflow as tf
n_hidden=20
n_units=200
act='selu'
out_act='softmax'
init='lecun_normal'
init_lr=0.0001
loss_def='categorical_crossentropy'
ep=100
ep_int=50
bat_size=32
max_lr=0.001
iterations=len(x_train)//bat_size*ep_int
opt=keras.optimizers.Nadam(learning_rate=0.0001)
loss=keras.losses.categorical_crossentropy

# %%
#Model Definition
import tensorflow as tf
from tensorflow import keras
#model1=Sequential()
ins=tf.keras.layers.Input(shape=x_train.shape[1:])
layer1=tf.keras.layers.Flatten(input_shape=x_train.shape[1:])(ins)
layer1=tf.keras.layers.Dense(units=n_units,activation=act,kernel_initializer=init)(layer1)
for i in range(n_hidden-1):
    layer1=tf.keras.layers.Dense(units=n_units,activation=act,kernel_initializer=init)(layer1)
    if(i%3)==0:
        layer1=tf.keras.layers.AlphaDropout(0.3)(layer1,training=True)
  
outs = tf.keras.layers.Dense(units=10,activation=out_act,kernel_initializer=init)(layer1)
model1=tf.keras.Model(inputs=ins,outputs=outs)
#model1.add()

# %%
import tensorflow as tf
from tensorflow import keras
K=tf.keras.backend
class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self,iterations,max_lr,start_lr=None,last_iterations=None,last_lr=None):
        self.iterations=iterations
        self.max_lr=max_lr
        self.start_lr=start_lr or max_lr/10
        self.last_iterations=last_iterations or iterations//10+1
        self.half_iteration=(iterations-self.last_iterations)//2
        self.last_lr=last_lr or self.start_lr/1000
        self.iteration=0
     
    def interpolate(self,iter1,iter2,rate1,rate2):
        temp1=((rate2-rate1)/(iter2-iter1))*(self.iteration-iter1)
        temp2=rate1+temp1
        return temp2
    
    def on_batch_begin(self,batch,logs):
        
        if self.iteration<self.half_iteration:
            rate=self.interpolate(0,self.half_iteration,self.start_lr,self.max_lr)
        
        elif self.iteration <2*self.half_iteration:
            
            rate=self.interpolate(self.half_iteration,2*self.half_iteration,self.max_lr,self.start_lr)

            
        else:
            rate=self.interpolate(2*self.half_iteration,self.iterations,self.start_lr,self.last_lr)
            rate=max(rate,self.last_lr)
            
        
        self.iteration+=1
        K.set_value(self.model.optimizer.lr,rate)
        
onec=OneCycleScheduler(iterations=iterations,max_lr=max_lr)

# %%
import tensorflow as tf
class custom_escb(tf.keras.callbacks.EarlyStopping):
    def __init__(self,monitor='val_loss', min_delta=0, patience=10, verbose=2, mode='auto',baseline=None, restore_best_weights=True,start_epoch=50):
        super(custom_escb,self).__init__()
        self.monitor=monitor
        self.patience=patience
        self.verbose=verbose
        self.start_epoch=start_epoch
                
    def on_epoch_end(self,epoch,logs=None):
        if(epoch>self.start_epoch):
            super().on_epoch_end(epoch,logs)
cescb=custom_escb()

# %%
#escb=tf.keras.callbacks.EarlyStopping(,restore_best_weights=True)
model1.compile(optimizer=opt,loss=loss_def,metrics=['accuracy'])

# %%
history=model1.fit(x=x_train,y=y_train,epochs=ep,validation_data=(x_val,y_val),batch_size=bat_size,callbacks=[onec,cescb])#
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 23s 563us/sample - loss: 2.2487 - accuracy: 0.1931 - val_loss: 2.0333 - val_accuracy: 0.2574
# Epoch 2/100
# 40000/40000 [==============================] - 20s 508us/sample - loss: 1.9204 - accuracy: 0.2943 - val_loss: 1.8664 - val_accuracy: 0.3276
# Epoch 3/100
# 40000/40000 [==============================] - 20s 507us/sample - loss: 1.8268 - accuracy: 0.3388 - val_loss: 1.8356 - val_accuracy: 0.3423
# Epoch 4/100
# 40000/40000 [==============================] - 20s 508us/sample - loss: 1.7778 - accuracy: 0.3645 - val_loss: 1.7924 - val_accuracy: 0.3682
# Epoch 5/100
# 40000/40000 [==============================] - 24s 604us/sample - loss: 1.7266 - accuracy: 0.3843 - val_loss: 1.7953 - val_accuracy: 0.3688
# Epoch 6/100
# 40000/40000 [==============================] - 27s 669us/sample - loss: 1.6941 - accuracy: 0.3985 - val_loss: 1.7506 - val_accuracy: 0.3920
# Epoch 7/100
# 40000/40000 [==============================] - 28s 691us/sample - loss: 1.6620 - accuracy: 0.4134 - val_loss: 1.7211 - val_accuracy: 0.4061
# Epoch 8/100
# 40000/40000 [==============================] - 28s 691us/sample - loss: 1.6325 - accuracy: 0.4269 - val_loss: 1.6940 - val_accuracy: 0.4084
# Epoch 9/100
# 40000/40000 [==============================] - 26s 654us/sample - loss: 1.6127 - accuracy: 0.4351 - val_loss: 1.7009 - val_accuracy: 0.4090
# Epoch 10/100
# 40000/40000 [==============================] - 26s 655us/sample - loss: 1.6115 - accuracy: 0.4348 - val_loss: 1.7209 - val_accuracy: 0.3981
# Epoch 11/100
# 40000/40000 [==============================] - 26s 655us/sample - loss: 1.5998 - accuracy: 0.4360 - val_loss: 1.6804 - val_accuracy: 0.4219
# Epoch 12/100
# 40000/40000 [==============================] - 26s 661us/sample - loss: 1.5868 - accuracy: 0.4425 - val_loss: 1.6647 - val_accuracy: 0.4255
# Epoch 13/100
# 40000/40000 [==============================] - 27s 674us/sample - loss: 1.5990 - accuracy: 0.4448 - val_loss: 1.6856 - val_accuracy: 0.4134
# Epoch 14/100
# 40000/40000 [==============================] - 27s 675us/sample - loss: 1.6118 - accuracy: 0.4342 - val_loss: 1.6989 - val_accuracy: 0.4223
# Epoch 15/100
# 40000/40000 [==============================] - 29s 726us/sample - loss: 1.6166 - accuracy: 0.4314 - val_loss: 1.7341 - val_accuracy: 0.4156
# Epoch 16/100
# 40000/40000 [==============================] - 29s 719us/sample - loss: 1.6221 - accuracy: 0.4348 - val_loss: 1.7577 - val_accuracy: 0.3887
# Epoch 17/100
# 40000/40000 [==============================] - 28s 706us/sample - loss: 1.6328 - accuracy: 0.4286 - val_loss: 1.7584 - val_accuracy: 0.3941
# Epoch 18/100
# 40000/40000 [==============================] - 27s 686us/sample - loss: 1.6816 - accuracy: 0.4044 - val_loss: 1.7934 - val_accuracy: 0.4004
# Epoch 19/100
# 40000/40000 [==============================] - 27s 671us/sample - loss: 1.6888 - accuracy: 0.4009 - val_loss: 1.8058 - val_accuracy: 0.3679
# Epoch 20/100
# 40000/40000 [==============================] - 20s 505us/sample - loss: 1.7262 - accuracy: 0.3853 - val_loss: 1.8003 - val_accuracy: 0.3593
# Epoch 21/100
# 40000/40000 [==============================] - 20s 508us/sample - loss: 2.4833 - accuracy: 0.3542 - val_loss: 2.1672 - val_accuracy: 0.2185
# Epoch 22/100
# 40000/40000 [==============================] - 20s 512us/sample - loss: 1.9280 - accuracy: 0.2993 - val_loss: 1.8717 - val_accuracy: 0.3299
# Epoch 23/100
# 40000/40000 [==============================] - 20s 512us/sample - loss: 1.7857 - accuracy: 0.3637 - val_loss: 1.8153 - val_accuracy: 0.3542
# Epoch 24/100
# 40000/40000 [==============================] - 20s 511us/sample - loss: 1.7526 - accuracy: 0.3758 - val_loss: 1.7793 - val_accuracy: 0.3801
# Epoch 25/100
# 40000/40000 [==============================] - 21s 526us/sample - loss: 1.7165 - accuracy: 0.3904 - val_loss: 1.7496 - val_accuracy: 0.3722
# Epoch 26/100
# 40000/40000 [==============================] - 22s 540us/sample - loss: 1.6920 - accuracy: 0.3907 - val_loss: 1.7445 - val_accuracy: 0.3760
# Epoch 27/100
# 40000/40000 [==============================] - 20s 508us/sample - loss: 1.6717 - accuracy: 0.4014 - val_loss: 1.7611 - val_accuracy: 0.3788
# Epoch 28/100
# 40000/40000 [==============================] - 20s 512us/sample - loss: 1.6783 - accuracy: 0.3997 - val_loss: 1.7676 - val_accuracy: 0.3688
# Epoch 29/100
# 40000/40000 [==============================] - 21s 521us/sample - loss: 2.5867 - accuracy: 0.3510 - val_loss: 1.8115 - val_accuracy: 0.3584
# Epoch 30/100
# 40000/40000 [==============================] - 20s 507us/sample - loss: 1.7009 - accuracy: 0.3711 - val_loss: 1.7527 - val_accuracy: 0.3648
# Epoch 31/100
# 40000/40000 [==============================] - 20s 509us/sample - loss: 1.6786 - accuracy: 0.3866 - val_loss: 1.7587 - val_accuracy: 0.3586
# Epoch 32/100
# 40000/40000 [==============================] - 20s 510us/sample - loss: 1.6483 - accuracy: 0.3937 - val_loss: 1.7401 - val_accuracy: 0.3726
# Epoch 33/100
# 40000/40000 [==============================] - 21s 513us/sample - loss: 1.6179 - accuracy: 0.4052 - val_loss: 1.6991 - val_accuracy: 0.3939
# Epoch 34/100
# 40000/40000 [==============================] - 20s 507us/sample - loss: 1.6040 - accuracy: 0.4194 - val_loss: 1.7018 - val_accuracy: 0.4044
# Epoch 35/100
# 40000/40000 [==============================] - 20s 511us/sample - loss: 1.5827 - accuracy: 0.4350 - val_loss: 1.6712 - val_accuracy: 0.4183
# Epoch 36/100
# 40000/40000 [==============================] - 23s 566us/sample - loss: 1.5715 - accuracy: 0.4433 - val_loss: 1.6587 - val_accuracy: 0.4243
# Epoch 37/100
# 40000/40000 [==============================] - 21s 521us/sample - loss: 1.5322 - accuracy: 0.4579 - val_loss: 1.6715 - val_accuracy: 0.4235
# Epoch 38/100
# 40000/40000 [==============================] - 21s 518us/sample - loss: 1.5202 - accuracy: 0.4679 - val_loss: 1.6348 - val_accuracy: 0.4360
# Epoch 39/100
# 40000/40000 [==============================] - 21s 517us/sample - loss: 1.4920 - accuracy: 0.4755 - val_loss: 1.6231 - val_accuracy: 0.4344
# Epoch 40/100
# 40000/40000 [==============================] - 21s 521us/sample - loss: 1.4795 - accuracy: 0.4816 - val_loss: 1.6177 - val_accuracy: 0.4372
# Epoch 41/100
# 40000/40000 [==============================] - 22s 549us/sample - loss: 1.4588 - accuracy: 0.4855 - val_loss: 1.5956 - val_accuracy: 0.4523
# Epoch 42/100
# 40000/40000 [==============================] - 21s 518us/sample - loss: 1.4433 - accuracy: 0.4955 - val_loss: 1.5770 - val_accuracy: 0.4527
# Epoch 43/100
# 40000/40000 [==============================] - 21s 518us/sample - loss: 1.4264 - accuracy: 0.5015 - val_loss: 1.5850 - val_accuracy: 0.4598
# Epoch 44/100
# 40000/40000 [==============================] - 21s 517us/sample - loss: 1.4046 - accuracy: 0.5060 - val_loss: 1.5712 - val_accuracy: 0.4607
# Epoch 45/100
# 40000/40000 [==============================] - 21s 537us/sample - loss: 1.3831 - accuracy: 0.5156 - val_loss: 1.5762 - val_accuracy: 0.4627
# Epoch 46/100
# 40000/40000 [==============================] - 21s 518us/sample - loss: 1.3694 - accuracy: 0.5209 - val_loss: 1.5709 - val_accuracy: 0.4623
# Epoch 47/100
# 40000/40000 [==============================] - 23s 577us/sample - loss: 1.3595 - accuracy: 0.5221 - val_loss: 1.5535 - val_accuracy: 0.4674
# Epoch 48/100
# 40000/40000 [==============================] - 28s 701us/sample - loss: 1.3521 - accuracy: 0.5264 - val_loss: 1.5539 - val_accuracy: 0.4685
# Epoch 49/100
# 40000/40000 [==============================] - 27s 685us/sample - loss: 1.3512 - accuracy: 0.5254 - val_loss: 1.5504 - val_accuracy: 0.4689
# Epoch 50/100
# 40000/40000 [==============================] - 28s 694us/sample - loss: 1.3423 - accuracy: 0.5271 - val_loss: 1.5519 - val_accuracy: 0.4739
# Epoch 51/100
# 40000/40000 [==============================] - 27s 683us/sample - loss: 1.3428 - accuracy: 0.5285 - val_loss: 1.5515 - val_accuracy: 0.4695
# Epoch 52/100
# 40000/40000 [==============================] - 27s 682us/sample - loss: 1.3401 - accuracy: 0.5266 - val_loss: 1.5604 - val_accuracy: 0.4667
# Epoch 53/100
# 40000/40000 [==============================] - 27s 682us/sample - loss: 1.3447 - accuracy: 0.5265 - val_loss: 1.5582 - val_accuracy: 0.4714
# Epoch 54/100
# 40000/40000 [==============================] - 26s 662us/sample - loss: 1.3450 - accuracy: 0.5276 - val_loss: 1.5548 - val_accuracy: 0.4709
# Epoch 55/100
# 40000/40000 [==============================] - 27s 667us/sample - loss: 1.3406 - accuracy: 0.5290 - val_loss: 1.5579 - val_accuracy: 0.4698
# Epoch 56/100
# 40000/40000 [==============================] - 27s 669us/sample - loss: 1.3388 - accuracy: 0.5284 - val_loss: 1.5557 - val_accuracy: 0.4662
# Epoch 57/100
# 40000/40000 [==============================] - 27s 682us/sample - loss: 1.3430 - accuracy: 0.5298 - val_loss: 1.5553 - val_accuracy: 0.4661
# Epoch 58/100
# 40000/40000 [==============================] - 27s 678us/sample - loss: 1.3398 - accuracy: 0.5299 - val_loss: 1.5583 - val_accuracy: 0.4666
# Epoch 59/100
# 40000/40000 [==============================] - 28s 689us/sample - loss: 1.3421 - accuracy: 0.5282 - val_loss: 1.5553 - val_accuracy: 0.4692
# Epoch 60/100
# 40000/40000 [==============================] - 28s 698us/sample - loss: 1.3379 - accuracy: 0.5302 - val_loss: 1.5562 - val_accuracy: 0.4719
# Epoch 61/100
# 40000/40000 [==============================] - 28s 695us/sample - loss: 1.3408 - accuracy: 0.5282 - val_loss: 1.5575 - val_accuracy: 0.4670
# Epoch 62/100
# 40000/40000 [==============================] - 27s 682us/sample - loss: 1.3407 - accuracy: 0.5296 - val_loss: 1.5557 - val_accuracy: 0.4694
# Epoch 63/100
# 40000/40000 [==============================] - 27s 680us/sample - loss: 1.3414 - accuracy: 0.5292 - val_loss: 1.5478 - val_accuracy: 0.4699
# Epoch 64/100
# 40000/40000 [==============================] - 27s 681us/sample - loss: 1.3401 - accuracy: 0.5314 - val_loss: 1.5527 - val_accuracy: 0.4675
# Epoch 65/100
# 40000/40000 [==============================] - 27s 682us/sample - loss: 1.3421 - accuracy: 0.5271 - val_loss: 1.5556 - val_accuracy: 0.4707
# Epoch 66/100
# 40000/40000 [==============================] - 27s 681us/sample - loss: 1.3405 - accuracy: 0.5281 - val_loss: 1.5517 - val_accuracy: 0.4707
# Epoch 67/100
# 40000/40000 [==============================] - 27s 681us/sample - loss: 1.3429 - accuracy: 0.5293 - val_loss: 1.5566 - val_accuracy: 0.4677
# Epoch 68/100
# 40000/40000 [==============================] - 27s 683us/sample - loss: 1.3379 - accuracy: 0.5296 - val_loss: 1.5560 - val_accuracy: 0.4665
# Epoch 69/100
# 40000/40000 [==============================] - 27s 681us/sample - loss: 1.3411 - accuracy: 0.5291 - val_loss: 1.5548 - val_accuracy: 0.4716
# Epoch 70/100
# 40000/40000 [==============================] - 27s 682us/sample - loss: 1.3375 - accuracy: 0.5307 - val_loss: 1.5591 - val_accuracy: 0.4686
# Epoch 71/100
# 40000/40000 [==============================] - 27s 683us/sample - loss: 1.3424 - accuracy: 0.5277 - val_loss: 1.5531 - val_accuracy: 0.4699
# Epoch 72/100
# 40000/40000 [==============================] - 27s 681us/sample - loss: 1.3389 - accuracy: 0.5296 - val_loss: 1.5574 - val_accuracy: 0.4691
# Epoch 73/100
# 40000/40000 [==============================] - 27s 683us/sample - loss: 1.3374 - accuracy: 0.5320 - val_loss: 1.5526 - val_accuracy: 0.4716
# Epoch 00073: early stopping

# %%
keras_plotter(history)

# %%
import numpy as np
y_pred=model1.predict(x_train)
y_pred_sparse=np.argmax(y_pred,axis=1)
y_train_sparse=np.argmax(y_train,axis=1)
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_train_sparse,y_pred_sparse)
print("Train systemLoss",acc)

import numpy as np
y_pred=model1.predict(x_val)
y_pred_sparse=np.argmax(y_pred,axis=1)
y_val_sparse=np.argmax(y_val,axis=1)
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_val_sparse,y_pred_sparse)
print("Validation Loss",acc)

import numpy as np
y_pred=model1.predict(x_test)
y_pred_sparse=np.argmax(y_pred,axis=1)
y_test_sparse=np.argmax(y_test,axis=1)
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test_sparse,y_pred_sparse)
print("Test Loss",acc)
# Out:
# Train systemLoss 0.5291
# Validation Loss 0.4657
# Test Loss 0.4777

# %%
def mc_droupout(model1,x_test,y_test):
    
    num_iter=100
    print("test")
    y_prob_pred_temp=np.zeros((10000,10,num_iter))

    for i in range(num_iter):

        y_prob_pred_temp[:,:,i]=model1.predict(x_test)

    y_prob_pred=y_prob_pred_temp.mean(axis=2)
    y_prob_pred_sparse=np.argmax(y_prob_pred,axis=1)
    return y_prob_pred_sparse

y_prob_pred_sparse=mc_droupout(model1,x_test,y_test)
y_test_sparse=np.argmax(y_test,axis=1)
    
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test_sparse,y_prob_pred_sparse)
print("MC Dropout Test Loss",acc)
# Out:
# test
# MC Dropout Test Loss 0.4967
